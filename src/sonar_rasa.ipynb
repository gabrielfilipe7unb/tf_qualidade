# %% [markdown]
# #### Libraries

# %%
import pandas as pd
import os

# %% [markdown]
# #### Setup config

# %%
ROOT_DIR = "../"

# Where the datasets are
DATA_PATH = os.path.join(ROOT_DIR, "data")
os.makedirs(DATA_PATH, exist_ok=True)

# %% [markdown]
# #### Dataframe settings

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# #### Data from JSON

# %%
df = pd.read_json('../data/sonar_rasa.json', lines=True)

# %%
df = df['measures'][0]

# %%
df
# Out:
# [{'metric': 'public_documented_api_density',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_maintainability_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_development_cost',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'effort_to_reach_maintainability_rating_a',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0'}]},
#  {'metric': 'new_lines', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_security_review_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_hotspots_reviewed',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0.0'}]},
#  {'metric': 'new_security_hotspots_reviewed',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_hotspots_reviewed_status',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_hotspots_to_review_status',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_security_hotspots_reviewed_status',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_security_hotspots_to_review_status',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'generated_lines',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'ncloc',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '75450'}]},
#  {'metric': 'ncloc_language_distribution',
#   'history': [{'date': '2020-12-03T19:23:35+0100',
#     'value': 'css=129;js=1074;py=74123;web=124'}]},
#  {'metric': 'generated_ncloc',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'classes',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '394'}]},
#  {'metric': 'files',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '471'}]},
#  {'metric': 'functions',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '4993'}]},
#  {'metric': 'statements',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '39120'}]},
#  {'metric': 'public_api', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'projects', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'comment_lines',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '13448'}]},
#  {'metric': 'comment_lines_density',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '15.1'}]},
#  {'metric': 'complexity',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '9706'}]},
#  {'metric': 'complexity_in_classes',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'complexity_in_functions',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'function_complexity_distribution',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'file_complexity_distribution',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'line_coverage',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_line_coverage',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_conditions_to_cover',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'branch_coverage',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_branch_coverage',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_minor_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_info_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'false_positive_issues',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0'}]},
#  {'metric': 'open_issues',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '357'}]},
#  {'metric': 'reopened_issues',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0'}]},
#  {'metric': 'confirmed_issues',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0'}]},
#  {'metric': 'code_smells',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '350'}]},
#  {'metric': 'new_code_smells',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'bugs',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '5'}]},
#  {'metric': 'new_bugs', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'info_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0'}]},
#  {'metric': 'new_security_hotspots',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'cognitive_complexity',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '7155'}]},
#  {'metric': 'skipped_tests',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'coverage', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_coverage', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'lines_to_cover',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_lines_to_cover',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_vulnerabilities',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_hotspots',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '48'}]},
#  {'metric': 'reliability_remediation_effort',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '52'}]},
#  {'metric': 'new_reliability_remediation_effort',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'reliability_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '5.0'}]},
#  {'metric': 'new_reliability_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_remediation_effort',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '60'}]},
#  {'metric': 'new_security_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_review_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '5.0'}]},
#  {'metric': 'duplicated_lines',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '2549'}]},
#  {'metric': 'new_duplicated_lines',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'duplicated_blocks',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '62'}]},
#  {'metric': 'new_duplicated_blocks',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'duplicated_files',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '20'}]},
#  {'metric': 'duplicated_lines_density',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '2.4'}]},
#  {'metric': 'new_duplicated_lines_density',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'duplications_data',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '357'}]},
#  {'metric': 'blocker_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '4'}]},
#  {'metric': 'major_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '112'}]},
#  {'metric': 'minor_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '29'}]},
#  {'metric': 'new_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_blocker_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_critical_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_major_violations',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'sqale_index',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '3665'}]},
#  {'metric': 'new_technical_debt',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'sqale_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '1.0'}]},
#  {'metric': 'development_cost',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '2263500'}]},
#  {'metric': 'sqale_debt_ratio',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '0.2'}]},
#  {'metric': 'new_sqale_debt_ratio',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'new_security_remediation_effort',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'security_rating',
#   'history': [{'date': '2020-12-03T19:23:35+0100', 'value': '2.0'}]},
#  {'metric': 'alert_status', 'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'quality_gate_details',
#   'history': [{'date': '2020-12-03T19:23:35+0100'}]},
#  {'metric': 'quality_profiles',
#   'history': [{'date': '2020-12-03T19:23:35+0100',
#     'value': '[{"key":"AXYp0JPKztk9DczeqA4b","language":"css","name":"Sonar way","rulesUpdatedAt":"2020-10-16T06:57:24+0000"},{"key":"AXYp0JPKztk9DczeqA4c","language":"js","name":"Sonar way","rulesUpdatedAt":"2020-11-16T08:31:07+0000"},{"key":"AXYp0JPKztk9DczeqA4f","language":"py","name":"Sonar way","rulesUpdatedAt":"2020-09-01T12:04:51+0000"},{"key":"AXYp0JPKztk9DczeqA4g","language":"web","name":"Sonar way","rulesUpdatedAt":"2020-11-16T08:32:30+0000"}]'}]}]

# %% [markdown]
# #### Data processing

# %%
metric = []

history1 = []
history2 = []

history1_value = []
history2_value = []

for i in range(len(df)):
    metric.append(df[i]['metric'])
    history1.append(df[i]['history'][0]['date'])
    try:
        history1_value.append(df[i]['history'][0]['value'])
    except KeyError as e:
        history1_value.append('-')

# %% [markdown]
# #### Data processed

# %%
sonar_rasa = pd.DataFrame([metric, history1, history1_value],
                          index=['metric', 'history_1', 'value_1']).T

# %%
sonar_rasa = sonar_rasa[sonar_rasa['value_1'] != '-'].reset_index(drop=True)

# %% [markdown]
# ##### Columns:
#
# - metric: metrica
# - history_1: histórico de versão 1
# - value_1: valor coletado no histórico 1

# %%
sonar_rasa
# Out:
#                                       metric                 history_1  \
# 0   effort_to_reach_maintainability_rating_a  2020-12-03T19:23:35+0100
# 1                 security_hotspots_reviewed  2020-12-03T19:23:35+0100
# 2                                      ncloc  2020-12-03T19:23:35+0100
# 3                ncloc_language_distribution  2020-12-03T19:23:35+0100
# 4                                    classes  2020-12-03T19:23:35+0100
# 5                                      files  2020-12-03T19:23:35+0100
# 6                                  functions  2020-12-03T19:23:35+0100
# 7                                 statements  2020-12-03T19:23:35+0100
# 8                              comment_lines  2020-12-03T19:23:35+0100
# 9                      comment_lines_density  2020-12-03T19:23:35+0100
# 10                                complexity  2020-12-03T19:23:35+0100
# 11                     false_positive_issues  2020-12-03T19:23:35+0100
# 12                               open_issues  2020-12-03T19:23:35+0100
# 13                           reopened_issues  2020-12-03T19:23:35+0100
# 14                          confirmed_issues  2020-12-03T19:23:35+0100
# 15                               code_smells  2020-12-03T19:23:35+0100
# 16                                      bugs  2020-12-03T19:23:35+0100
# 17                           info_violations  2020-12-03T19:23:35+0100
# 18                      cognitive_complexity  2020-12-03T19:23:35+0100
# 19                         security_hotspots  2020-12-03T19:23:35+0100
# 20            reliability_remediation_effort  2020-12-03T19:23:35+0100
# 21                        reliability_rating  2020-12-03T19:23:35+0100
# 22               security_remediation_effort  2020-12-03T19:23:35+0100
# 23                    security_review_rating  2020-12-03T19:23:35+0100
# 24                          duplicated_lines  2020-12-03T19:23:35+0100
# 25                         duplicated_blocks  2020-12-03T19:23:35+0100
# 26                          duplicated_files  2020-12-03T19:23:35+0100
# 27                  duplicated_lines_density  2020-12-03T19:23:35+0100
# 28                                violations  2020-12-03T19:23:35+0100
# 29                        blocker_violations  2020-12-03T19:23:35+0100
# 30                          major_violations  2020-12-03T19:23:35+0100
# 31                          minor_violations  2020-12-03T19:23:35+0100
# 32                               sqale_index  2020-12-03T19:23:35+0100
# 33                              sqale_rating  2020-12-03T19:23:35+0100
# 34                          development_cost  2020-12-03T19:23:35+0100
# 35                          sqale_debt_ratio  2020-12-03T19:23:35+0100
# 36                           security_rating  2020-12-03T19:23:35+0100
# 37                          quality_profiles  2020-12-03T19:23:35+0100
#
#                                               value_1
# 0                                                   0
# 1                                                 0.0
# 2                                               75450
# 3                    css=129;js=1074;py=74123;web=124
# 4                                                 394
# 5                                                 471
# 6                                                4993
# 7                                               39120
# 8                                               13448
# 9                                                15.1
# 10                                               9706
# 11                                                  0
# 12                                                357
# 13                                                  0
# 14                                                  0
# 15                                                350
# 16                                                  5
# 17                                                  0
# 18                                               7155
# 19                                                 48
# 20                                                 52
# 21                                                5.0
# 22                                                 60
# 23                                                5.0
# 24                                               2549
# 25                                                 62
# 26                                                 20
# 27                                                2.4
# 28                                                357
# 29                                                  4
# 30                                                112
# 31                                                 29
# 32                                               3665
# 33                                                1.0
# 34                                            2263500
# 35                                                0.2
# 36                                                2.0
# 37  [{"key":"AXYp0JPKztk9DczeqA4b","language":"css...

# %%
sonar_rasa.to_excel('../data/sonar_rasa.xlsx')
